# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Users/joestar/Desktop/machine learning/AIML Dataset.csv')

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df['isFraud'].value_counts()[1]/df.shape[0]
# Out:
# np.float64(0.001290820448180152)

# %%
df['type'].value_counts().plot(kind='bar',title='transaction type')
plt.xlabel('transaction type')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
fraud_by_type=df.groupby('type')['isFraud'].mean().sort_values(ascending=False)

# %%
fraud_by_type
# Out:
# type
# TRANSFER    0.007688
# CASH_OUT    0.001840
# CASH_IN     0.000000
# DEBIT       0.000000
# PAYMENT     0.000000
# Name: isFraud, dtype: float64

# %%
fraud_by_type.plot(kind='bar',title="fraud rate by type")
plt.ylabel('fraud rate')
# Out:
# Text(0, 0.5, 'fraud rate')

# %%
df["amount"].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df['amount']),bins=100,kde=True,color='green')
plt.title("amount distribition in log")
plt.xlabel("log(amount+1)")
# Out:
# Text(0.5, 0, 'log(amount+1)')

# %%
sns.boxplot(data=df[df["amount"]< 50000],x='isFraud',y="amount")
plt.title("amount vs fraud restricted to under 50000")
plt.show()

# %%
df["balance difference"]=df['oldbalanceOrg']-df['newbalanceOrig']
df["balance destination"]= df['newbalanceDest']-df['oldbalanceDest']

# %%
df["balance difference"]
# Out:
# 0             9839.64
# 1             1864.28
# 2              181.00
# 3              181.00
# 4            11668.14
#               ...
# 6362615     339682.13
# 6362616    6311409.28
# 6362617    6311409.28
# 6362618     850002.52
# 6362619     850002.52
# Name: balance difference, Length: 6362620, dtype: float64

# %%
(df["balance destination"]<0).sum()
# Out:
# np.int64(1238864)

# %%
(df["balance difference"] < 0).sum()
# Out:
# np.int64(1399253)

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balance difference', 'balance destination'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    balance difference  balance destination
# 0             9839.64                  0.0
# 1             1864.28                  0.0

# %%
fraud_per_step=df[df["isFraud"]==1]['step'].value_counts().sort_index()
plt.plot(fraud_per_step.index,fraud_per_step.values,label="fraud per step")
plt.xlabel("step")
plt.ylabel("fraud over time")
plt.grid("true")
plt.show()
df.drop(columns="step",inplace=True)

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balance difference  balance destination
# 0             9839.64                  0.0
# 1             1864.28                  0.0
# ...

# %%
top_senders=df["nameOrig"].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C1902386530    3
# C363736674     3
# C545315117     3
# C724452879     3
# C1784010646    3
# C1677795071    3
# C1462946854    3
# C1999539787    3
# C2098525306    3
# C400299098     3
# Name: count, dtype: int64

# %%
top_recivers=df["nameDest"].value_counts().head(10)
top_recivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_name=df[df["isFraud"]==1]["nameOrig"].value_counts().head(10)
fraud_name
# Out:
# nameOrig
# C1305486145    1
# C755286039     1
# C973279667     1
# C258213312     1
# C1640703547    1
# C1127265876    1
# C317779855     1
# C1064034527    1
# C1141104763    1
# C1966863341    1
# Name: count, dtype: int64

# %%
fraud_type=df[df["type"].isin(["TRANSFER","CASH_OUT"])]
fraud_type
# Out:
#              type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        TRANSFER      181.00  C1305486145         181.00             0.0
# 3        CASH_OUT      181.00   C840083671         181.00             0.0
# 15       CASH_OUT   229133.94   C905080434       15325.00             0.0
# 19       TRANSFER   215310.30  C1670993182         705.00             0.0
# 24       TRANSFER   311685.89  C1984094095       10835.00             0.0
# ...           ...         ...          ...            ...             ...
# 6362615  CASH_OUT   339682.13   C786484425      339682.13             0.0
# 6362616  TRANSFER  6311409.28  C1529008245     6311409.28             0.0
# 6362617  CASH_OUT  6311409.28  C1162922333     6311409.28             0.0
# 6362618  TRANSFER   850002.52  C1685995037      850002.52             0.0
# 6362619  CASH_OUT   850002.52  C1280323807      850002.52             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...

# %%
fraud_type["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_type,x="type",hue="isFraud")
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
corr=df[['amount', 'oldbalanceOrg', 'newbalanceOrig',
        'oldbalanceDest', 'newbalanceDest', 'isFraud']]

# %%
corr
# Out:
#              amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0           9839.64      170136.00       160296.36            0.00
# 1           1864.28       21249.00        19384.72            0.00
# 2            181.00         181.00            0.00            0.00
# 3            181.00         181.00            0.00        21182.00
# 4          11668.14       41554.00        29885.86            0.00
# ...             ...            ...             ...             ...
# 6362615   339682.13      339682.13            0.00            0.00
# 6362616  6311409.28     6311409.28            0.00            0.00
# 6362617  6311409.28     6311409.28            0.00        68488.84
# 6362618   850002.52      850002.52            0.00            0.00
# 6362619   850002.52      850002.52            0.00      6510099.11
#
#          newbalanceDest  isFraud
# 0                  0.00        0
# 1                  0.00        0
# 2                  0.00        1
# ...

# %%
df.columns
# Out:
# Index(['type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balance difference', 'balance destination'],
#       dtype='object')

# %%
df
# Out:
#              type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0         PAYMENT     9839.64  C1231006815      170136.00       160296.36
# 1         PAYMENT     1864.28  C1666544295       21249.00        19384.72
# 2        TRANSFER      181.00  C1305486145         181.00            0.00
# 3        CASH_OUT      181.00   C840083671         181.00            0.00
# 4         PAYMENT    11668.14  C2048537720       41554.00        29885.86
# ...           ...         ...          ...            ...             ...
# 6362615  CASH_OUT   339682.13   C786484425      339682.13            0.00
# 6362616  TRANSFER  6311409.28  C1529008245     6311409.28            0.00
# 6362617  CASH_OUT  6311409.28  C1162922333     6311409.28            0.00
# 6362618  TRANSFER   850002.52  C1685995037      850002.52            0.00
# 6362619  CASH_OUT   850002.52  C1280323807      850002.52            0.00
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...
